# %% [markdown]
# ## 什么是数据结构

# %% [markdown]
# 数据结构是值的集合，值之间可以有关系。
#
# 可以把数据结构视作是不同的存储装置：
#
# ![image.png](attachment:04efc487-45eb-4481-b36f-b4544de39d19.png)
#
# 不同的存储装置可以被用来存储不同的对象或者实现不同的存储功能。

# %% [markdown]
# ## 计算机是如何存储data的

# %% [markdown]
# ![image.png](attachment:08ba9fd3-5caf-4d64-87aa-96bbf0a3a4b3.png)
#
# 为了让计算机能够运行代码，计算机需要跟踪变量，数字，字符串和数组等，这些变量都会存储在RAM中。
#
# 用来进行长期存储的数据则会被存储到Storage中，存储到RAM和Storage的区别在于，数据是否会在计算机断电之后被保存下来。
#
# 我们可以这样去看待RAM：
#
# ![image.png](attachment:bd61c741-6d7f-4745-a90b-ef6edf7d0a8f.png)
#
# 这则是对几种不同的编程语言的简单对比：
#
# ![image.png](attachment:62ba027c-d418-4f2b-9001-b91bb27f5712.png)
