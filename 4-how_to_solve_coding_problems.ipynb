# %% [markdown]
# ## 技能

# %% [markdown]
# 面试官在寻找什么技能？
#
# 1. 分析技能：思考的过程和如何寻找出解决问题的逻辑
# 2. 编码技能：将问题的解答通过代码的方式来进行实现
# 3. 技术技能
# 4. 交流技能：能够进行好的交流

# %% [markdown]
# ## 编码技能

# %% [markdown]
# 如下图所示：
#
# ![image.png](attachment:3aba39dd-b954-4f39-a807-c83aab88a618.png)
#
# 这些知识点是在面试的时候通常会被考到的知识点。
