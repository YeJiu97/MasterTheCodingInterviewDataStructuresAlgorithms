# %% [markdown]
# ## 关于本课程

# %% [markdown]
# 下图展示了面试和面试常见的问题：
#
# ![image.png](attachment:5514d680-5925-440a-a718-a39006d79640.png)
#
# 下图则是数据结构和算法的重点：
#
# ![image.png](attachment:82ab816e-843d-4af4-95e6-6f335c880003.png)
